# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Ts=0.1
f=0.1
th=np.arange(-3, 3, Ts)
tx=np.arange(0,50, Ts)
h=np.sin(2*np.pi*th)/(2*np.pi*th)
plt.plot(h)
x=np.sign(np.sin(2*np.pi*f*tx))
plt.plot(x)
plt.show()
y=np.convolve(h,x)

plt.plot(y)
